# %%
import pandas as pd

# %%
df = pd.read_csv("https://raw.githubusercontent.com/mwaskom/seaborn-data/master/tips.csv")

# %%
df.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 244 entries, 0 to 243
# Data columns (total 7 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   total_bill  244 non-null    float64
#  1   tip         244 non-null    float64
#  2   sex         244 non-null    object
#  3   smoker      244 non-null    object
#  4   day         244 non-null    object
#  5   time        244 non-null    object
#  6   size        244 non-null    int64
# dtypes: float64(2), int64(1), object(4)
# memory usage: 13.5+ KB

# %%
df.describe()
# Out:
#        total_bill         tip        size
# count  244.000000  244.000000  244.000000
# mean    19.785943    2.998279    2.569672
# std      8.902412    1.383638    0.951100
# min      3.070000    1.000000    1.000000
# 25%     13.347500    2.000000    2.000000
# 50%     17.795000    2.900000    2.000000
# 75%     24.127500    3.562500    3.000000
# max     50.810000   10.000000    6.000000

# %%
df["day"].value_counts()
# Out:
# day
# Sat     87
# Sun     76
# Thur    62
# Fri     19
# Name: count, dtype: int64

# %%
df["total_bill"].mean()
# Out:
# np.float64(19.78594262295082)

# %%
df.groupby("day")["tip"].mean()
# Out:
# day
# Fri     2.734737
# Sat     2.993103
# Sun     3.255132
# Thur    2.771452
# Name: tip, dtype: float64

# %%
## There are 4 rows, the day with the highest average tip is Sunday and it is surprising how high it is on that day

# %%
import pandas as pd

# %%
df = pd.read_csv("https://raw.githubusercontent.com/mwaskom/seaborn-data/master/tips.csv")

# %%
df.isnull().sum()
# Out:
# total_bill    0
# tip           0
# sex           0
# smoker        0
# day           0
# time          0
# size          0
# dtype: int64

# %%
df.isnull().mean()
# Out:
# total_bill    0.0
# tip           0.0
# sex           0.0
# smoker        0.0
# day           0.0
# time          0.0
# size          0.0
# dtype: float64

# %%
df_drop = df.dropna()

# %%
df_fill = df.fillna(0)

# %%
## Drop or fill missing rows depending on scenario.

# %%
df.columns
# Out:
# Index(['total_bill', 'tip', 'sex', 'smoker', 'day', 'time', 'size'], dtype='object')

# %%
df = df.rename(columns={"total_bill": "total_bill_gbp"})

# %%
df.head()
# Out:
#    total_bill_gbp   tip     sex smoker  day    time  size
# 0           16.99  1.01  Female     No  Sun  Dinner     2
# 1           10.34  1.66    Male     No  Sun  Dinner     3
# 2           21.01  3.50    Male     No  Sun  Dinner     3
# 3           23.68  3.31    Male     No  Sun  Dinner     2
# 4           24.59  3.61  Female     No  Sun  Dinner     4

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 244 entries, 0 to 243
# Data columns (total 7 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   total_bill_gbp  244 non-null    float64
#  1   tip             244 non-null    float64
#  2   sex             244 non-null    object
#  3   smoker          244 non-null    object
#  4   day             244 non-null    object
#  5   time            244 non-null    object
#  6   size            244 non-null    int64
# dtypes: float64(2), int64(1), object(4)
# memory usage: 13.5+ KB

# %%
df.describe()
# Out:
#        total_bill_gbp         tip        size
# count      244.000000  244.000000  244.000000
# mean        19.785943    2.998279    2.569672
# std          8.902412    1.383638    0.951100
# min          3.070000    1.000000    1.000000
# 25%         13.347500    2.000000    2.000000
# 50%         17.795000    2.900000    2.000000
# 75%         24.127500    3.562500    3.000000
# max         50.810000   10.000000    6.000000

# %%
## Data Cleaning summary
### Performed checks to investigate the presence of missing values. Changed the name of total bill to total bill gbp. These steps matter because it allows us to make corrections/changes in our data

# %%
## Day 3 - Filtering, Sorting and Analysis

# %%
# Only dinner records

# %%
df_dinner = df[df["time"] == "Dinner"]

# %%
df_dinner.head()
# Out:
#    total_bill_gbp   tip     sex smoker  day    time  size
# 0           16.99  1.01  Female     No  Sun  Dinner     2
# 1           10.34  1.66    Male     No  Sun  Dinner     3
# 2           21.01  3.50    Male     No  Sun  Dinner     3
# 3           23.68  3.31    Male     No  Sun  Dinner     2
# 4           24.59  3.61  Female     No  Sun  Dinner     4

# %%
df_dinner.shape
# Out:
# (176, 7)

# %%
len(df_dinner)
# Out:
# 176

# %%
## There are 176 dinner records, more than expected

# %%
# Dinner and Smoker

# %%
df_dinner_smokers = df[(df["time"] == "Dinner") & (df["smoker"] == "Yes")]

# %%
df_dinner_smokers.head()
# Out:
#     total_bill_gbp   tip   sex smoker  day    time  size
# 56           38.01  3.00  Male    Yes  Sat  Dinner     4
# 58           11.24  1.76  Male    Yes  Sat  Dinner     2
# 60           20.29  3.21  Male    Yes  Sat  Dinner     2
# 61           13.81  2.00  Male    Yes  Sat  Dinner     2
# 62           11.02  1.98  Male    Yes  Sat  Dinner     2

# %%
df_dinner_smokers.shape
# Out:
# (70, 7)

# %%
## This seems a small subset. Not sure why it would matter

# %%
# Highest total bills

# %%
df.sort_values(by="total_bill_gbp", ascending=False).head()
# Out:
#      total_bill_gbp    tip   sex smoker  day    time  size
# 170           50.81  10.00  Male    Yes  Sat  Dinner     3
# 212           48.33   9.00  Male     No  Sat  Dinner     4
# 59            48.27   6.73  Male     No  Sat  Dinner     4
# 156           48.17   5.00  Male     No  Sun  Dinner     6
# 182           45.35   3.50  Male    Yes  Sun  Dinner     3

# %%
df.sort_values(by="tip", ascending=False).head()
# Out:
#      total_bill_gbp    tip   sex smoker   day    time  size
# 170           50.81  10.00  Male    Yes   Sat  Dinner     3
# 212           48.33   9.00  Male     No   Sat  Dinner     4
# 23            39.42   7.58  Male     No   Sat  Dinner     4
# 59            48.27   6.73  Male     No   Sat  Dinner     4
# 141           34.30   6.70  Male     No  Thur   Lunch     6

# %%
## The highest bills do not always result in the highest tips

# %%
df.groupby("day")["total_bill_gbp"].mean()
# Out:
# day
# Fri     17.151579
# Sat     20.441379
# Sun     21.410000
# Thur    17.682742
# Name: total_bill_gbp, dtype: float64

# %%
## Sunday has the highest average bill

# %%
df.groupby("smoker")["tip"].mean()
# Out:
# smoker
# No     2.991854
# Yes    3.008710
# Name: tip, dtype: float64

# %%
## Smokers tip more on average

# %%
df.groupby("size")["tip"].mean()
# Out:
# size
# 1    1.437500
# 2    2.582308
# 3    3.393158
# 4    4.135405
# 5    4.028000
# 6    5.225000
# Name: tip, dtype: float64

# %%
## The bigger the group size, the greater the mean tip

# %%
## Day 4 - Grouping and Aggregation

# %%
# Average bill by day

# %%
df.groupby("day")["total_bill_gbp"].mean()
# Out:
# day
# Fri     17.151579
# Sat     20.441379
# Sun     21.410000
# Thur    17.682742
# Name: total_bill_gbp, dtype: float64

# %%
# Average tip by time

# %%
df.groupby("time")["tip"].mean()
# Out:
# time
# Dinner    3.102670
# Lunch     2.728088
# Name: tip, dtype: float64

# %%
## Sunday has the highest average total bill. Dinner is more profitable tipping wise

# %%
df.groupby("day").agg(
    avg_bill=("total_bill_gbp", "mean"),
    avg_tip=("tip", "mean"),
    count=("total_bill_gbp", "count")
)
# Out:
#        avg_bill   avg_tip  count
# day
# Fri   17.151579  2.734737     19
# Sat   20.441379  2.993103     87
# Sun   21.410000  3.255132     76
# Thur  17.682742  2.771452     62

# %%
## Count is important as it allows us to study which days are busiest. Saturday looks the most reliable as it yields the greatest earinings

# %%
df.groupby(["day", "time"])["total_bill_gbp"].mean()
# Out:
# day   time
# Fri   Dinner    19.663333
#       Lunch     12.845714
# Sat   Dinner    20.441379
# Sun   Dinner    21.410000
# Thur  Dinner    18.780000
#       Lunch     17.664754
# Name: total_bill_gbp, dtype: float64

# %%
df.groupby(["day", "smoker"])["tip"].mean()
# Out:
# day   smoker
# Fri   No        2.812500
#       Yes       2.714000
# Sat   No        3.102889
#       Yes       2.875476
# Sun   No        3.167895
#       Yes       3.516842
# Thur  No        2.673778
#       Yes       3.030000
# Name: tip, dtype: float64

# %%
## Significantly lower mean bills during lunchtime friday compares to every other time. I would ask smoker average bills grouped by day and time

# %%
## Day 5 - Week 1 Mini Analysis

# %%
### Analysis Questions

# %%
### 1. Which day generates the highest average bill?

# %%
df.groupby("day")["total_bill_gbp"].mean()
# Out:
# day
# Fri     17.151579
# Sat     20.441379
# Sun     21.410000
# Thur    17.682742
# Name: total_bill_gbp, dtype: float64

# %%
### Sunday is the day with the highest average bill

# %%
### 2. Do smokers tip more than non-smokers?

# %%
df.groupby(["day", "smoker"])["tip"].mean()
# Out:
# day   smoker
# Fri   No        2.812500
#       Yes       2.714000
# Sat   No        3.102889
#       Yes       2.875476
# Sun   No        3.167895
#       Yes       3.516842
# Thur  No        2.673778
#       Yes       3.030000
# Name: tip, dtype: float64

# %%
### Yes, on average smokers tip more

# %%
### 3. Does group size affect tipping?

# %%
df.groupby("size")["tip"].mean()
# Out:
# size
# 1    1.437500
# 2    2.582308
# 3    3.393158
# 4    4.135405
# 5    4.028000
# 6    5.225000
# Name: tip, dtype: float64

# %%
### On average, the higher the group size, the greater the (average) tip

# %%
### 4. Is dinner more profitable than lunch?

# %%
df.groupby(["day", "time"])["total_bill_gbp"].mean()
# Out:
# day   time
# Fri   Dinner    19.663333
#       Lunch     12.845714
# Sat   Dinner    20.441379
# Sun   Dinner    21.410000
# Thur  Dinner    18.780000
#       Lunch     17.664754
# Name: total_bill_gbp, dtype: float64

# %%
### The data we have supports the idea that dinner is on average more profitable than lunch, however we dont have the total bill for saturday or sunday lunch so we dont have enough to comapre

# %%
## Day 6 - Derived Columns & Feature Engineering

# %%
df["tip_pct"] = df["tip"] / df["total_bill_gbp"] * 100

# %%
df.head()
# Out:
#    total_bill_gbp   tip     sex smoker  day    time  size    tip_pct
# 0           16.99  1.01  Female     No  Sun  Dinner     2   5.944673
# 1           10.34  1.66    Male     No  Sun  Dinner     3  16.054159
# 2           21.01  3.50    Male     No  Sun  Dinner     3  16.658734
# 3           23.68  3.31    Male     No  Sun  Dinner     2  13.978041
# 4           24.59  3.61  Female     No  Sun  Dinner     4  14.680765

# %%
df["tip_pct"].describe()
# Out:
# count    244.000000
# mean      16.080258
# std        6.107220
# min        3.563814
# 25%       12.912736
# 50%       15.476977
# 75%       19.147549
# max       71.034483
# Name: tip_pct, dtype: float64

# %%
### Average tip percentage = 16%. Max tip is so much higher than the lowest tip (71% v 3.5%)

# %%
df.groupby("day")["tip_pct"].mean()
# Out:
# day
# Fri     16.991303
# Sat     15.315172
# Sun     16.689729
# Thur    16.127563
# Name: tip_pct, dtype: float64

# %%
df.groupby("smoker")["tip_pct"].mean()
# Out:
# smoker
# No     15.932846
# Yes    16.319604
# Name: tip_pct, dtype: float64

# %%
### Smokers tip slightly more percentage wise than non-smokers. Compared with raw tip values, they match up quite similar

# %%
df["bill_size"] = pd.cut(
    df["total_bill_gbp"],
    bins=[0, 10, 20, 40, 100],
    labels=["Small", "Medium", "Large", "Very Large"]
)

# %%
df["bill_size"].value_counts()
# Out:
# bill_size
# Medium        130
# Large          87
# Small          17
# Very Large     10
# Name: count, dtype: int64

# %%
### Medium size bills, as I wouldve expected, are the most common. Categorising like this helps make more agruments and conclusions with regards to data

# %%
df.groupby("bill_size")["tip_pct"].mean()
# Out:
# /var/folders/0n/dpk0lv3553bfbmtc_53z_sth0000gn/T/ipykernel_24671/2528106914.py:1: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   df.groupby("bill_size")["tip_pct"].mean()
# bill_size
# Small         23.420672
# Medium        16.564244
# Large         14.404402
# Very Large    11.889688
# Name: tip_pct, dtype: float64

# %%
### Larger bills tend to tip a lower percentage. This may be because the total bill price being high would inadvertively make the tip seem smaller in contrast, as opposed to paying the same tip with a smaller bill

# %%
## Day 7 - Data Visualisation Basics

# %%
import seaborn as sns
import matplotlib.pyplot as plt

sns.histplot(df["total_bill_gbp"], bins=20)
plt.title("Distribution of Total Bills")
plt.xlabel("Total Bill (GBP)")
# Out:
# Text(0.5, 0, 'Total Bill (GBP)')

# %%
### The distribution is skewed to the left. Most bills cluster between 10 and 30 GBP

# %%
sns.barplot(x="day", y="tip_pct", data=df)
plt.title("Average Tip Percentage by Day")
plt.ylabel("Tip Percentage")
# Out:
# Text(0, 0.5, 'Tip Percentage')

# %%
### Friday has the highest average tip

# %%
sns.barplot(x="bill_size", y="tip_pct", data=df)
plt.title("Tip Percentage by Bill Size")
plt.ylabel("Tip Percentage")
# Out:
# Text(0, 0.5, 'Tip Percentage')

# %%
### Larger bills do not proportionally tip more. This could be because if both people with small and large bills tip the same, it would look smaller proportionally with larger bills as opposed to smaller bills

# %%
## Key Insights

# %%
### Customers tip proportionally more on smaller bills, Weekends show higher tip percentages, tip behavior varies more by day than bill size

# %%
df.groupby("day")["tip_pct"].mean().sort_values(ascending=False)
# Out:
# day
# Fri     16.991303
# Sun     16.689729
# Thur    16.127563
# Sat     15.315172
# Name: tip_pct, dtype: float64

# %%
## Day 10 - SQL with Python

# %%
import sqlite3

# %%
import pandas as pd

# %%
conn = sqlite3.connect("restaurant.db")

# %%
df.to_sql("tips", conn, if_exists="replace", index=False)
# Out:
# 244

# %%
query = """
SELECT day, AVG(tip_pct) AS avg_tip_pct
FROM tips
GROUP BY day
ORDER BY avg_tip_pct DESC;
"""

# %%
sql_df = pd.read_sql(query, conn)
sql_df
# Out:
#     day  avg_tip_pct
# 0   Fri    16.991303
# 1   Sun    16.689729
# 2  Thur    16.127563
# 3   Sat    15.315172

# %%
import seaborn as sns
import matplotlib.pyplot as plt

sns.barplot(x="day", y="avg_tip_pct", data=sql_df)
plt.title("Average Tip Percentage by Day (SQL)")
# Out:
# Text(0.5, 1.0, 'Average Tip Percentage by Day (SQL)')

# %%
### In my opinion, there isn't that much difference between the two. Maybe the interface is much easier to use than groupby() in pandas. Companies may like SQL more because it is better for dealing with larger data sets.

# %%
## Day 11: SQL JOINs

# %%
customer_data = {
    "customer_id": [1,2,3,4],
    "customer_type": ["Regular", "VIP", "Regular", "VIP"]
}

customers = pd.DataFrame(customer_data)

customers
# Out:
#    customer_id customer_type
# 0            1       Regular
# 1            2           VIP
# 2            3       Regular
# 3            4           VIP

# %%
customers.to_sql("customers", conn, if_exists="replace", index=False)
# Out:
# 4

# %%
import numpy as np

# %%
df["customer_id"] = np.random.randint(1, 5, size=len(df))
df.head()
# Out:
#    total_bill_gbp   tip     sex smoker  day    time  size    tip_pct  \
# 0           16.99  1.01  Female     No  Sun  Dinner     2   5.944673
# 1           10.34  1.66    Male     No  Sun  Dinner     3  16.054159
# 2           21.01  3.50    Male     No  Sun  Dinner     3  16.658734
# 3           23.68  3.31    Male     No  Sun  Dinner     2  13.978041
# 4           24.59  3.61  Female     No  Sun  Dinner     4  14.680765
#
#   bill_size  customer_id
# 0    Medium            3
# 1    Medium            2
# 2     Large            2
# 3     Large            1
# 4     Large            4

# %%
df.to_sql("tips", conn, if_exists="replace", index=False)
# Out:
# 244

# %%
query = """
SELECT tips.day, tips.tip_pct, customers.customer_type
FROM tips
INNER JOIN customers
ON tips.customer_id = customers.customer_id;
"""

joined_df = pd.read_sql(query, conn)
joined_df.head()
# Out:
#    day    tip_pct customer_type
# 0  Sun   5.944673       Regular
# 1  Sun  16.054159           VIP
# 2  Sun  16.658734           VIP
# 3  Sun  13.978041       Regular
# 4  Sun  14.680765           VIP

# %%
query = """
SELECT tips.day, tips.tip_pct, customers.customer_type
FROM tips
LEFT JOIN customers
ON tips.customer_id = customers.customer_id;
"""

pd.read_sql(query, conn)
# Out:
#       day    tip_pct customer_type
# 0     Sun   5.944673       Regular
# 1     Sun  16.054159           VIP
# 2     Sun  16.658734           VIP
# 3     Sun  13.978041       Regular
# 4     Sun  14.680765           VIP
# ..    ...        ...           ...
# 239   Sat  20.392697       Regular
# 240   Sat   7.358352       Regular
# 241   Sat   8.822232       Regular
# 242   Sat   9.820426       Regular
# 243  Thur  15.974441       Regular
#
# [244 rows x 3 columns]

# %%
### Left JOIN is safer as it prevents data from being lossed or misidentified. Inner Join would hide data if there are no matches

# %%
# Mini Project: Restaurant Tipping Analysis

# %%
## Business Question: Average tips are higher on weekdays and smokers tend to tip more than non-smokers

# %%
df.head()
# Out:
#    total_bill_gbp   tip     sex smoker  day    time  size    tip_pct  \
# 0           16.99  1.01  Female     No  Sun  Dinner     2   5.944673
# 1           10.34  1.66    Male     No  Sun  Dinner     3  16.054159
# 2           21.01  3.50    Male     No  Sun  Dinner     3  16.658734
# 3           23.68  3.31    Male     No  Sun  Dinner     2  13.978041
# 4           24.59  3.61  Female     No  Sun  Dinner     4  14.680765
#
#   bill_size  customer_id
# 0    Medium            3
# 1    Medium            2
# 2     Large            2
# 3     Large            1
# 4     Large            4

# %%
df.shape
# Out:
# (244, 10)

# %%
## The dataset used is from a restaurant over four days; Thursday to Sunday. There are 244 Rows and 10 Columns. There is data for tip percentage, bill size and even customer Identity.

# %%
query = """
SELECT day, AVG(tip_pct) AS avg_tip_pct
FROM tips
GROUP BY day
ORDER BY avg_tip_pct DESC;
"""

# %%
sql_results = pd.read_sql(query, conn)
sql_results
# Out:
#     day  avg_tip_pct
# 0   Fri    16.991303
# 1   Sun    16.689729
# 2  Thur    16.127563
# 3   Sat    15.315172

# %%
## Friday has the highest average tip percentage

# %%
query = """
SELECT customers.customer_type, AVG(tips.tip_pct) AS avg_tip_pct
FROM tips
LEFT JOIN customers
ON tips.customer_id = customers.customer_id
GROUP BY customers.customer_type;
"""

# %%
pd.read_sql(query, conn)
# Out:
#   customer_type  avg_tip_pct
# 0       Regular    15.727416
# 1           VIP    16.384618

# %%
## Regulars have a higher tip percentage than VIPs. Limitations will be the lack of data of the other days and the fact that customer IDs are randomly assigned

# %%
sns.barplot(x="day", y="avg_tip_pct", data=sql_results)
plt.title("Average Tip Percentage by Day")
plt.ylabel("Tip Percentage")
# Out:
# Text(0, 0.5, 'Tip Percentage')

# %%
## Chart shows Average tipping percentage per day

# %%
## Key Insights

### Tipping behaviour varies more by day than by bill size
### Weekend days tend to show higher tip percentages
### Customer type shows modest differences, though data is limited
